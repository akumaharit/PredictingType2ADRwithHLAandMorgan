# %%
#ดึงข้อมูลจาก log_notclean_Allele
#ก็คือรายการอัลลีนจากฐานข้อมูลดิบ โดยยังไม่ต้องคลีนอะไรใด ๆ เพราะเรากำลังจะเอา sequence ที่เกี่ยวข้องไปใส่ใน dataset ก่อนคลีน)

file = open('../3 - Cleaning & Transforming Data//log_notclean_Allele.txt', 'r')
allele_list = []
for x in file.readlines():
    x = x.split()
    allele = x[0]
    allele_list.append(allele)
allele_list.sort()
allele_list = list(allele_list[1:])
print(allele_list)
file.close()

file = open('dataset_Allele.txt', 'w')
# Out:
# ['A*01', 'A*01:01', 'A*01:02', 'A*01:03', 'A*02', 'A*02:01', 'A*02:02', 'A*02:03', 'A*02:05', 'A*02:06', 'A*02:07', 'A*02:08', 'A*02:10', 'A*02:11', 'A*02:12', 'A*02:81', 'A*03', 'A*03:01', 'A*03:02', 'A*11', 'A*11:01', 'A*11:10', 'A*11:53', 'A*2', 'A*21:02', 'A*23:01', 'A*24', 'A*24:01', 'A*24:02', 'A*24:03', 'A*24:05', 'A*24:07', 'A*24:10', 'A*24:13', 'A*24:20', 'A*25:01', 'A*26:01', 'A*26:02', 'A*26:03', 'A*26:05', 'A*26:08', 'A*26:09', 'A*29:01', 'A*29:02', 'A*30:01', 'A*30:02', 'A*30:04', 'A*31:01', 'A*32:01', 'A*32:04', 'A*33', 'A*33:01', 'A*33:03', 'A*34:02', 'A*36:01', 'A*36:02', 'A*43:01', 'A*66:01', 'A*68:01', 'A*68:02', 'A*68:03', 'A*69:01', 'A*74:01', 'A*80:01', 'A*92:19', 'B*07', 'B*07:02', 'B*07:05', 'B*07:11', 'B*08:01', 'B*13:01', 'B*13:02', 'B*13:10', 'B*13:15', 'B*14.01', 'B*14.02', 'B*14:01', 'B*14:02', 'B*15:01', 'B*15:02', 'B*15:03', 'B*15:05', 'B*15:07', 'B*15:10', 'B*15:11', 'B*15:12', 'B*15:13', 'B*15:15', 'B*15:17', 'B*15:18', 'B*15:19', 'B*15:21', 'B*15:24',
# ...

# %%
# Out:
# []

# %%
# Out:
# 'B*15:02        134\nB*58:01         86\nA*24:02         62\nB*13:01         62\nB*51:01         60\nA*31:01         60\nB*40:01         51\nA*33:03         51\nA*02:01         46\nA*02:06         46\nA*11:01         46\nB*46:01         45\nB*15:01         44\nB*44:03         41\nB*57:01         39\nA*26:01         35\nA*03:01         33\nB*07:02         32\nB*52:01         31\nB*44:02         31\nA*01:01         30\nB*38:01         28\nDRB1*07:01      27\nB*35:01         27\nB*54:01         26\nB*55:02         26\nB*56:01         25\nA*30:01         25\nA*32:01         25\nB*18:01         25\nB*08:01         23\nB*38:02         22\nC*03:04         22\nC*03:02         22\nB*07:05         21\nB*27:05         21\nA*68:01         20\nB*13:02         20\nB*41:01         20\nA*33:01         19\nB*35:03         19\nB*15:11         19\nB*49:01         18\nB*40:06         18\nDRB1*15:01      17\nC*04:01         17\nDRB1*04:05      17\nB*55:01         17\nC*08:01         17\nB*35:02         1
# ...
